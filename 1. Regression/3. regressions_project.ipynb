# %% [markdown]
# Her er jeres første rigtige opgave! I skal lave bruge [yfinance](https://mercantec.notion.site/yfinance-8f05decbf9a040659da38616e432ed62?pvs=4) også kaldet Yahoo Finance, til at trække data ned på jeres yndlingsaktie! I skal herfra lave en regressionsmodel på dataet. Det involvere at splitte dataet op i træningsdata og testdata.
# Nedenunder er der lige et code-snippet til at få jer startet!

# %% [markdown]
# Vi skal bruge følgende pakker til at starte vores projekt, en del af dem kender I. Pandas fra første dag, datetime har i nok arbejdet med lignende pakker før. [yfinance](https://mercantec.notion.site/yfinance-8f05decbf9a040659da38616e432ed62?pvs=4) er den som er linket til ovenfor og har alt det data vi skal bruge. Til sidste er der matplitlib, den er ikke strengt nødvendig for vores projekt, men det hjælper ofte at få et visuelt billede på! Dokumentation kan findes [her](https://mercantec.notion.site/MatPlotLib-bb10bec44c8e4bc28ac511017dbc895d?pvs=4)

# %%
import tensorflow as tf
import numpy as np
import yfinance as yf
import pandas as pd
from datetime import date, timedelta
from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import seaborn as sns
import os
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Vi bruger datetime pakken til at sætte et startspunkt og et slutpunkt. Startspunktet er for 365 dage siden og slutpunktet er for 2 dage siden!

# %%
Start = date.today() - timedelta(365)
Start.strftime('%Y-%m-%d')

End = date.today() + timedelta(2)
End.strftime('%Y-%m-%d')
# Out:
# '2024-01-12'

# %% [markdown]
# Vi laver en funktion som tager en "ticker" ind, altså en aktie.
# Her bruger vi så Pandas, pd, til at en dataframe som indeholder vores data omkring den valgte ticker, med slut og startsdato som definere før.

# %%
def closing_price(ticker):
    Asset = pd.DataFrame(yf.download(ticker, start=Start,
      end=End))     
    return Asset

# %% [markdown]
# Nu kan vi bruge vores funktion til at se på vores data. Her bruger vi Microsoft aktien, MSFT. Standarten er at vi for dato, åbningsprisen, højeste og laveste på dagen, lukke prisen og den justerede lukkepris. Vi kan så bruge matplotlib

# %%
microsoft = closing_price('MSFT') 
print(microsoft)
plt.plot(microsoft['Adj Close'])
plt.show()
training_df = closing_price('MSFT')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-10  227.759995  231.309998  227.330002  228.850006  226.838638
# 2023-01-11  231.289993  235.949997  231.110001  235.770004  233.697815
# 2023-01-12  235.259995  239.899994  233.559998  238.509995  236.413742
# 2023-01-13  237.000000  239.369995  234.919998  239.229996  237.127426
# 2023-01-17  237.970001  240.910004  237.089996  240.350006  238.237595
# ...                ...         ...         ...         ...         ...
# 2024-01-03  369.010010  373.260010  368.510010  370.600006  370.600006
# 2024-01-04  370.670013  373.100006  367.170013  367.940002  367.940002
# 2024-01-05  368.970001  372.059998  366.500000  367.750000  367.750000
# 2024-01-08  369.299988  375.200012  369.010010  374.690002  374.690002
# 2024-01-09  372.010010  375.989990  371.190002  375.790009  375.790009
#
#               Volume
# Date
# 2023-01-10  27033900
# 2023-01-11  28669300
# 2023-01-12  27269500
# 2023-01-13  21333300
# 2023-01-17  29831300
# ...              ...
# 2024-01-03  23083500
# 2024-01-04  20901500
# 2024-01-05  20987000
# 2024-01-08  23134000
# 2024-01-09  20559646
#
# [251 rows x 6 columns]
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Opgaven
#
# Opgaven går nu på at I skal bruge jeres viden omkring regression på at lave en model som kan forudsige hvad aktie prisen bliver over den næste periode eller forhåbenligt bare en retning.
#
# Det er ikke målet at I skal finde en model som gør det, men at I skal lege rundt med det. De værktøjer som vi har fået indtil videre, er ikke nok til at kunne lave en model som har noget grundlag. Det data vi for er heller ikke nok.
#
# I kan tage inspiration ud fra dokumenterne her [regression](https://github.com/MAGS-Template/MachineLearning/blob/main/1.%20Regression/1.%20regression.ipynb) og [regression med data](https://github.com/MAGS-Template/MachineLearning/blob/main/1.%20Regression/2.%20regression_with_data.ipynb) - det er filerne i samme mappe som den her!

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1,
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error.
  model.compile(optimizer=tf.keras.optimizers.experimental.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs.
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch

  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch.
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

# %%
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = random_examples[feature].max()
  y1 = trained_bias + (np.average(trained_weight) * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, rmse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 70
batch_size = 30

# Specify the feature and the label.
my_feature = "Close"  
my_label="Open" 


# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df,
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/70
# 9/9 [==============================] - 1s 3ms/step - loss: 6860.7705 - root_mean_squared_error: 82.8298
# Epoch 2/70
# 9/9 [==============================] - 0s 4ms/step - loss: 2418.8999 - root_mean_squared_error: 49.1823
# Epoch 3/70
# 9/9 [==============================] - 0s 3ms/step - loss: 805.3591 - root_mean_squared_error: 28.3789
# Epoch 4/70
# 9/9 [==============================] - 0s 4ms/step - loss: 191.5339 - root_mean_squared_error: 13.8396
# Epoch 5/70
# 9/9 [==============================] - 0s 8ms/step - loss: 36.0326 - root_mean_squared_error: 6.0027
# Epoch 6/70
# 9/9 [==============================] - 0s 12ms/step - loss: 16.2928 - root_mean_squared_error: 4.0364
# Epoch 7/70
# 9/9 [==============================] - 0s 11ms/step - loss: 15.8679 - root_mean_squared_error: 3.9835
# Epoch 8/70
# 9/9 [==============================] - 0s 9ms/step - loss: 16.1663 - root_mean_squared_error: 4.0207
# Epoch 9/70
# 9/9 [==============================] - 0s 6ms/step - loss: 16.6360 - root_mean_squared_error: 4.0787
# Epoch 10/70
# 9/9 [==============================] - 0s 8ms/step - loss: 16.6953 - root_mean_squared_error: 4.0860
# Epoch 11/70
# 9/9 [==============================] - 0s 6ms/step - loss: 15.9430 - root_mean_squared_error: 3.9929
# Epoch 12/70
# 9/9 [==============================] - 0s 5ms/step - loss: 21.6175 - root_mean_squared_error: 4.6495
# Epoch 13/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.7260 - root_mean_squared_error: 4.4414
# Epoch 14/70
# 9/9 [==============================] - 0s 4ms/step - loss: 17.5517 - root_mean_squared_error: 4.1895
# Epoch 15/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.0217 - root_mean_squared_error: 4.2452
# Epoch 16/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.1608 - root_mean_squared_error: 4.3773
# Epoch 17/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.7344 - root_mean_squared_error: 4.3283
# Epoch 18/70
# 9/9 [==============================] - 0s 3ms/step - loss: 18.7433 - root_mean_squared_error: 4.3293
# Epoch 19/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.8092 - root_mean_squared_error: 4.4508
# Epoch 20/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.4480 - root_mean_squared_error: 4.1771
# Epoch 21/70
# 9/9 [==============================] - 0s 3ms/step - loss: 20.7095 - root_mean_squared_error: 4.5508
# Epoch 22/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.1186 - root_mean_squared_error: 4.1375
# Epoch 23/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.3918 - root_mean_squared_error: 4.1703
# Epoch 24/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.9758 - root_mean_squared_error: 4.4694
# Epoch 25/70
# 9/9 [==============================] - 0s 3ms/step - loss: 20.3535 - root_mean_squared_error: 4.5115
# Epoch 26/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.3442 - root_mean_squared_error: 4.3982
# Epoch 27/70
# 9/9 [==============================] - 0s 3ms/step - loss: 18.4188 - root_mean_squared_error: 4.2917
# Epoch 28/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.0124 - root_mean_squared_error: 4.3603
# Epoch 29/70
# 9/9 [==============================] - 0s 2ms/step - loss: 18.4785 - root_mean_squared_error: 4.2987
# Epoch 30/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.7774 - root_mean_squared_error: 4.3333
# Epoch 31/70
# 9/9 [==============================] - 0s 3ms/step - loss: 20.2829 - root_mean_squared_error: 4.5037
# Epoch 32/70
# 9/9 [==============================] - 0s 5ms/step - loss: 16.8233 - root_mean_squared_error: 4.1016
# Epoch 33/70
# 9/9 [==============================] - 0s 5ms/step - loss: 19.5051 - root_mean_squared_error: 4.4165
# Epoch 34/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.8137 - root_mean_squared_error: 4.3375
# Epoch 35/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.5305 - root_mean_squared_error: 4.1869
# Epoch 36/70
# 9/9 [==============================] - 0s 4ms/step - loss: 19.0235 - root_mean_squared_error: 4.3616
# Epoch 37/70
# 9/9 [==============================] - 0s 2ms/step - loss: 20.6030 - root_mean_squared_error: 4.5391
# Epoch 38/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.4269 - root_mean_squared_error: 4.4076
# Epoch 39/70
# 9/9 [==============================] - 0s 2ms/step - loss: 17.9641 - root_mean_squared_error: 4.2384
# Epoch 40/70
# 9/9 [==============================] - 0s 3ms/step - loss: 22.9683 - root_mean_squared_error: 4.7925
# Epoch 41/70
# 9/9 [==============================] - 0s 2ms/step - loss: 16.4128 - root_mean_squared_error: 4.0513
# Epoch 42/70
# 9/9 [==============================] - 0s 3ms/step - loss: 18.1038 - root_mean_squared_error: 4.2549
# Epoch 43/70
# 9/9 [==============================] - 0s 2ms/step - loss: 18.1565 - root_mean_squared_error: 4.2610
# Epoch 44/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.3426 - root_mean_squared_error: 4.3980
# Epoch 45/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.6101 - root_mean_squared_error: 4.1964
# Epoch 46/70
# 9/9 [==============================] - 0s 4ms/step - loss: 17.8961 - root_mean_squared_error: 4.2304
# Epoch 47/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.9798 - root_mean_squared_error: 4.4699
# Epoch 48/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.4849 - root_mean_squared_error: 4.2994
# Epoch 49/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.1473 - root_mean_squared_error: 4.3758
# Epoch 50/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.8206 - root_mean_squared_error: 4.3383
# Epoch 51/70
# 9/9 [==============================] - 0s 2ms/step - loss: 20.5043 - root_mean_squared_error: 4.5282
# Epoch 52/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.2264 - root_mean_squared_error: 4.1505
# Epoch 53/70
# 9/9 [==============================] - 0s 2ms/step - loss: 16.8217 - root_mean_squared_error: 4.1014
# Epoch 54/70
# 9/9 [==============================] - 0s 3ms/step - loss: 16.5624 - root_mean_squared_error: 4.0697
# Epoch 55/70
# 9/9 [==============================] - 0s 2ms/step - loss: 24.4360 - root_mean_squared_error: 4.9433
# Epoch 56/70
# 9/9 [==============================] - 0s 3ms/step - loss: 15.8006 - root_mean_squared_error: 3.9750
# Epoch 57/70
# 9/9 [==============================] - 0s 3ms/step - loss: 21.5458 - root_mean_squared_error: 4.6417
# Epoch 58/70
# 9/9 [==============================] - 0s 4ms/step - loss: 16.5654 - root_mean_squared_error: 4.0701
# Epoch 59/70
# 9/9 [==============================] - 0s 3ms/step - loss: 20.0712 - root_mean_squared_error: 4.4801
# Epoch 60/70
# 9/9 [==============================] - 0s 5ms/step - loss: 16.9188 - root_mean_squared_error: 4.1132
# Epoch 61/70
# 9/9 [==============================] - 0s 3ms/step - loss: 18.8814 - root_mean_squared_error: 4.3453
# Epoch 62/70
# 9/9 [==============================] - 0s 4ms/step - loss: 20.5099 - root_mean_squared_error: 4.5288
# Epoch 63/70
# 9/9 [==============================] - 0s 4ms/step - loss: 18.4768 - root_mean_squared_error: 4.2985
# Epoch 64/70
# 9/9 [==============================] - 0s 3ms/step - loss: 17.9590 - root_mean_squared_error: 4.2378
# Epoch 65/70
# 9/9 [==============================] - 0s 5ms/step - loss: 16.7955 - root_mean_squared_error: 4.0982
# Epoch 66/70
# 9/9 [==============================] - 0s 4ms/step - loss: 16.9731 - root_mean_squared_error: 4.1198
# Epoch 67/70
# 9/9 [==============================] - 0s 3ms/step - loss: 22.3190 - root_mean_squared_error: 4.7243
# Epoch 68/70
# 9/9 [==============================] - 0s 5ms/step - loss: 18.5414 - root_mean_squared_error: 4.3060
# Epoch 69/70
# 9/9 [==============================] - 0s 3ms/step - loss: 18.5241 - root_mean_squared_error: 4.3040
# Epoch 70/70
# 9/9 [==============================] - 0s 3ms/step - loss: 19.5359 - root_mean_squared_error: 4.4199
#
# The learned weight for your model is 0.9967
# The learned bias for your model is 0.3141
# C:\Users\jona70k6\AppData\Local\Temp\ipykernel_18036\3458599614.py:17: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("\nThe learned weight for your model is %.4f" % weight)
# C:\Users\jona70k6\AppData\Local\Temp\ipykernel_18036\3458599614.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("The learned bias for your model is %.4f\n" % bias )

# %%
# Creating training dataset
training_df = closing_price('MSFT') 
train_dataset = microsoft.sample(frac=0.8, random_state=0)
test_dataset = microsoft.drop(train_dataset.index)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Separate features and labels
train_features = train_dataset.drop('Close', axis=1)  # Assuming 'Close' is the target variable
test_features = test_dataset.drop('Close', axis=1)

train_labels = train_dataset['Close']
test_labels = test_dataset['Close']

# %%
horsepower = np.array(train_features['Open'])

# Normalize the data
horsepower_normalizer = layers.Normalization(input_shape=[1,], axis=None)
horsepower_normalizer.adapt(np.array(train_features['Open']))

# %%
def plot_horsepower(x, y):
  # Plot the predictions
  plt.scatter(train_features['Open'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Microsoft')
  plt.ylabel('Close price')
  plt.legend()
  plt.show()

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Mean Absolute Error')
  plt.legend()
  plt.grid(True)

# %%
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.5))
  return model

# %%
dnn_horsepower_model = build_and_compile_model(horsepower_normalizer)

# %%
# %%time
history = dnn_horsepower_model.fit(
    train_features['Open'],
    train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)
# Out:
# CPU times: total: 9.61 s
# Wall time: 8.53 s

# %%
plot_loss(history)
# Generate predictions
x = np.linspace(0.0, 250, 251)
y = dnn_horsepower_model.predict(x)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
plot_horsepower(x, y)
